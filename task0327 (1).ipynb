# %% [markdown]
# # 📊 Application Development Assignment
#
# ## REST API Data Processing using Python
#
# - Name: 살
# - Student ID: 2555047

# %%
# !pip install gradio

import requests
import pandas as pd
import json

# %%
url_users = "https://jsonplaceholder.typicode.com/users"
response = requests.get(url_users)

users = response.json()

df_users = pd.DataFrame(users)
df_users.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %%
address_df = pd.json_normalize(df_users['address'])
address_df.head()
# Out:
#               street      suite           city     zipcode   geo.lat  \
# 0        Kulas Light   Apt. 556    Gwenborough  92998-3874  -37.3159
# 1      Victor Plains  Suite 879    Wisokyburgh  90566-7771  -43.9509
# 2  Douglas Extension  Suite 847  McKenziehaven  59590-4157  -68.6102
# 3        Hoeger Mall   Apt. 692    South Elvis  53919-4257   29.4572
# 4       Skiles Walks  Suite 351     Roscoeview       33263  -31.8129
#
#      geo.lng
# 0    81.1496
# 1   -34.4618
# 2   -47.0653
# 3  -164.2990
# 4    62.5342

# %%
url_posts = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url_posts)

posts = response.json()

df_posts = pd.DataFrame(posts)
df_posts.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
even_posts = df_posts[df_posts.index % 2 == 0]
even_posts
# Out:
#     userId  id                                              title  \
# 0        1   1  sunt aut facere repellat provident occaecati e...
# 2        1   3  ea molestias quasi exercitationem repellat qui...
# 4        1   5                                 nesciunt quas odio
# 6        1   7                               magnam facilis autem
# 8        1   9  nesciunt iure omnis dolorem tempora et accusan...
# 10       2  11                   et ea vero quia laudantium autem
# 12       2  13  dolorum ut in voluptas mollitia et saepe quo a...
# 14       2  15                            eveniet quod temporibus
# 16       2  17  fugit voluptas sed molestias voluptatem provident
# 18       2  19          adipisci placeat illum aut reiciendis qui
# 20       3  21  asperiores ea ipsam voluptatibus modi minima q...
# 22       3  23                      maxime id vitae nihil numquam
# 24       3  25                      rem alias distinctio quo quis
# ...

# %%
even_posts.to_excel("even_posts.xlsx", index=False)

# %%
import gradio as gr

def search_user(user_id):
    url = "https://jsonplaceholder.typicode.com/posts"
    params = {"userId": user_id}

    response = requests.get(url, params=params)
    data = response.json()

    df = pd.DataFrame(data)
    return df

interface = gr.Interface(
    fn=search_user,
    inputs="number",
    outputs="dataframe",
    title="Search Posts by User ID"
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5f5b21a27bda9497df.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5f5b21a27bda9497df.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
naver = requests.get("https://www.naver.com")
google = requests.get("https://www.google.com")

print("NAVER HEADERS:\n", naver.headers)
print("\nGOOGLE HEADERS:\n", google.headers)
# Out:
# NAVER HEADERS:
#  {'Content-Type': 'text/html; charset=UTF-8', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'x-frame-options': 'DENY', 'x-xss-protection': '1; mode=block', 'strict-transport-security': 'max-age=63072000; includeSubdomains', 'referrer-policy': 'unsafe-url', 'Content-Encoding': 'gzip', 'Server': 'nfront', 'Date': 'Thu, 02 Apr 2026 14:22:08 GMT', 'Content-Length': '48473', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding'}
#
# GOOGLE HEADERS:
# ...
